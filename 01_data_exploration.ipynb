# %% [markdown]
# # Data Exploration
#
# This notebook explores the initial business data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv('../data/raw/sample_business_data.csv')

# Display info
df.info()
df.head()

# %% [markdown]
# ## Basic Analysis
#
# Here you can add charts, statistics, and more...
